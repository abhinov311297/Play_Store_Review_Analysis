# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinov311297/Play_Store_Review_Analysis/blob/main/Team_Notebook_of_Play_store_app_review_analysis_Capstone_project_by_Vivek_Kumar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market.**
# # **Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.**
# ## **Explore and analyze the data to discover key factors responsible for app engagement and success.**

# %% [markdown]
# ![Google-Play-Store-1280.webp](data:image/webp;base64,...)

# %% [markdown]
# ## **“Where there is data smoke, there is business fire.” — Thomas Redman**
#
# Thomas C. Redman, president of Data Quality Solutions, helps start-ups and multi-nationals, senior executives, chief data officers, and leaders buried deep in their organizations chart their courses to data-driven futures, with special emphasis on quality and analytics.
#
# It is correctly said that data is needed for startup growth in a region as it help us to understand the bussiness environment,taste of the population and previous record of the region.
#
# I have tried to analyse the data set given as a project and able to further develop my understanding in Data Sceince and able to grab some fruitful conclusion which would help getting grilled in one of most important field of corporate world.
#
# So,now lets starts playing with the data!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path= '/content/drive/MyDrive/CAPSTONE_PROJECT-1-EDA/'
df = pd.read_csv(path+'Play Store Data.csv')

# %% [markdown]
# # **Load dataframes for visual analysis**

# %%
df.head() #to see the sample data
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
df.columns #to check the name of columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.info #to get basic information of data
# Out:
# <bound method DataFrame.info of                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]>

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.size
# Out:
# 140933

# %% [markdown]
# ***Details of Each Columns of playstore_df DataFrame***
#
# |Columns_Name|Details_of_Contains|
# |------------|-------------------|
# |**App**| The app name|
# |**Category**|Categorical label, which describes which broad category the app belongs to.|
# |**Rating**|Continuous variable with a range from 0.0 to 5.0, which describes the average rating the app has received from the users.|
# |**Reviews**|Continuous variable describing the number of reviews that the app received.|
# |**Size**|The size of the app. The suffix M is used for megabytes, while the suffix K is used for kilobytes.|
# |**Installs**|Categorical label that describes the number of installs.|
# |**Type**|Label that indicates whether the app is free or paid.|
# |**Price**|The price value for the paid apps.|
# |**Content Rating**|Categorical rating that indicates the age group for which the app is suitable.|
# |**Genre**| Smicolon-separated list of genres to which the app belongs.|
# |**Last Update**|The date the app was last updated.|
# |**Current Version**|The current version of the app as specified by the developers.|
# |**Android Version**|The Android operating system the app is compatible with.|

# %% [markdown]
# ## ***USER REVIEW***

# %% [markdown]
# We have been also provided some information related to the review of the users.
#
# Here clearly we can see the sentimental orientation of the users toward different apps and its extent.
#
# Lets see some of the info in given data set of user reviews!

# %%
user_rev = pd.read_csv(path+'User Reviews.csv')

# %%
user_rev.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
user_rev.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
user_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# # ***Category Wise Distribution***

# %% [markdown]
# Since there is a large number of apps and many apps are doing more or less same work or related to same genre,thus it is better to analyse their feature and popularity based on their category.
#
# Category provides us the different dimensions for need of the population.
#
# As Alain De Botton rightly said “To grow interested in any piece of information, we need somewhere to 'put' it, which means some way of connecting it to an issue we already now how to care about.”
# Categorization help us to simplify the large chunk of information for our better understanding and processing and making a relationship.
#
# Thus we first find the category wise distribution of Apps.It will give us which dimension of needs user generally like to pursue most.

# %%
number_in_category=df.groupby('Category').size().sort_values(ascending=False)

# %%
print(number_in_category)
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# 1.9                       1
# dtype: int64

# %% [markdown]
# **Plotting distribution of Category**

# %%
plt.rcParams['figure.figsize'] = (20, 15)
def autopct(pct): # only show the label when it's > 10%
    return ('%.2f' % pct) if pct > 5 else ''
number_in_category.plot(kind='pie',autopct=autopct)

# %% [markdown]
# This pie chart showed us the Family related apps are the most number in availability, followed by Games which is generally preferred by Children.
# This two constitute neary 30% of the available Apps.
#
# Look like developers have a better understanding of family needs.
# Other unexpected result,is having so much less number of Beauty Apps despite nearly 50% women in our society.This pointed toward the digital divide where female still constitute very less number of users as compared to male.
#
# Declined trend in Comic Apps also shows the changing orientation of the children.In our childhood,comic consist very important source of entertainment,but today we can percieve the changes,feeling sad!

# %% [markdown]
# # ***Category Wise Distribution Of Installs***

# %% [markdown]
# Now after analysing the availability of Apps on Playstore, we would move toward the result which is the number of Installs which actually matters!
#
# This will actually shows the category wise demand of the Apps and will help us to estimate the taste of the population and their interest.
#
# Analyzing this could help in making future strategy for App Developers to attract larger users base.

# %%
df['Installs'].value_counts() #checking different amount of installs
# Out:
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             907
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Free                 1
# Name: Installs, dtype: int64

# %% [markdown]
# **Cleaning of data**

# %% [markdown]
# Install data having data type of String with symbol like commas,plus.Thus for comparing and analysing , need to be converted in Integer type.It would help us in plotting the Numerical Value on chart.

# %%
df['Installs'] = df['Installs'].apply(lambda x: x.replace(',', '')) # removing comma(,)

# %%
df['Installs'] = df['Installs'].apply(lambda x: x.strip('+')) #removing plus(+) symbol for converting into numerical form(int)

# %%
df['Installs'] = df['Installs'].replace("Free", '0') #replacing 'Free' with '0' for fusing into same data type

# %%
df['Installs'] = df['Installs'].astype('int') #converting data type of string into int.

# %%
category_wise_install=df.groupby(['Category'])[['Installs']].sum().sort_values(by='Installs',ascending=False) #category wise grouping of number of Installs 
print(category_wise_install)
# Out:
#                         Installs
# Category
# GAME                 35086024415
# COMMUNICATION        32647276251
# PRODUCTIVITY         14176091369
# SOCIAL               14069867902
# TOOLS                11452771915
# FAMILY               10258263505
# PHOTOGRAPHY          10088247655
# NEWS_AND_MAGAZINES    7496317760
# TRAVEL_AND_LOCAL      6868887146
# VIDEO_PLAYERS         6222002720
# SHOPPING              3247848785
# ENTERTAINMENT         2869160000
# PERSONALIZATION       2325494782
# BOOKS_AND_REFERENCE   1921469576
# SPORTS                1751174498
# HEALTH_AND_FITNESS    1583072512
# BUSINESS              1001914865
# FINANCE                876648734
# EDUCATION              871452000
# MAPS_AND_NAVIGATION    724281890
# LIFESTYLE              537643539
# WEATHER                426100520
# FOOD_AND_DRINK         273898751
# DATING                 264310807
# HOUSE_AND_HOME         168712461
# ART_AND_DESIGN         124338100
# LIBRARIES_AND_DEMO      62995910
# COMICS                  56086150
# MEDICAL                 53257437
# AUTO_AND_VEHICLES       53130211
# PARENTING               31521110
# BEAUTY                  27197050
# EVENTS                  15973161
# 1.9                            0

# %% [markdown]
# **TOP 5 Installed APP**

# %%
top5_installed=df[df['Installs']==1000000000]
top5_installed[['App','Category','Installs']].head()
# Out:
#                                           App             Category    Installs
# 152                         Google Play Books  BOOKS_AND_REFERENCE  1000000000
# 335  Messenger – Text and Video Chat for Free        COMMUNICATION  1000000000
# 336                        WhatsApp Messenger        COMMUNICATION  1000000000
# 338              Google Chrome: Fast & Secure        COMMUNICATION  1000000000
# 340                                     Gmail        COMMUNICATION  1000000000

# %% [markdown]
# Quite interesting, messengers apps dominating the top installs,it shows the now messengers Apps have became one of the basic needs of a person.
# Historically from sign to letter and from telephone to now messenger,how the world is changing year by year.

# %% [markdown]
# **Plotting Category Wise Installs**

# %%
plt.rcParams['figure.figsize'] = (15, 10)
install_axis=[]
category_axis=[]
for j in range(len(category_wise_install)):
    install_axis.append(category_wise_install.Installs[j])
    category_axis.append(category_wise_install.index[j])

# %%
plt.xlabel("Installs", size=15)
plt.ylabel("Category",size=15)
sns.barplot(x = install_axis, y= category_axis, alpha =0.9)
plt.title("Installs", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Installs')

# %% [markdown]
# Now after analysing the availability of Apps on Playstore,we would move toward the result which is the number of Installs which actually matters!
#
# Quiet Shocking!despite having most number of Family related Apps,their installs are very less compared to their availibility even not come in top 5 category wise.
# Game category able to dominate in both in their number of availability and Installs.
#
# Communication related apps have impressed us despite havping less availability able to secure the position of top installs,which shows the high demand of for this category of Apps.
#
# Less number of installs in Health and Education category make us to think about the less awareness among people in using digital technology.Government need to work in difusing sense of trust among citizen on technology change and their optimal use.
#
# Minimal installs in Beauty category shows the female are still lagging behind male in using Apps due to several reasons.
#
# This graph is also showing the social aspect of the population!

# %% [markdown]
# Ploting the Top 10 Installed Apps in any category

# %%
plt.rcParams['figure.figsize'] = (12, 7)
def Top10_installed_app_in_any_category(str):
    str = str.upper()
    top10 = df[df['Category'] == str]
    top10apps = top10.sort_values(by='Installs', ascending=False).head(10)
    plt.figure(figsize=(12,7))
    plt.title('Top 10 Installed Apps',size = 25);    
    graph = sns.barplot(x = top10apps['App'], y = top10apps['Installs'])
    graph.set_xticklabels(graph.get_xticklabels(), rotation= 45, horizontalalignment='right');

# %%
Top10_installed_app_in_any_category('ART_AND_DESIGN')

# %% [markdown]
# If we select a category,for example 'ART AND DESIGN',here we can see stark difference between to Apps like Sketch-Draw & Paint and other Apps.
# Reason could be anything lik peple's interest,easy to use,price,commercial nature etc.
#
# People still like more simple drawing and painting rather than editing,which show the despite arrival of new features,orientation of people still toward the older way of art.
#
# We already saw in Movie Titanic!

# %% [markdown]
# # ***Category Wise Rating***

# %% [markdown]
# Now we ll move to Rating related to the different category.
#
# Rating is the measure how much users like it services.
#
# Here we ll see the average rating in every category and try to analyse which category of Apps people liked the most in terms of their performance.
#
# This would help the developers to find the shortcoming in their Apps to which they rectify to improve ratings

# %% [markdown]
# **Data Cleaning**

# %%
df.loc[df['Rating']==np.NaN,'Rating']=0 #replacing Rating of np.Nan with 0 and 19 with 1.9
df.loc[df['Rating']==19, 'Rating']=1.9

# %%
category_wise_rating=df.groupby('Category')['Rating'].mean().reset_index().sort_values(by='Rating',ascending=False) #category wise grouping of rating
print(category_wise_rating)
# Out:
#                Category    Rating
# 11               EVENTS  4.435556
# 9             EDUCATION  4.389032
# 1        ART_AND_DESIGN  4.358065
# 4   BOOKS_AND_REFERENCE  4.346067
# 24      PERSONALIZATION  4.335987
# 23            PARENTING  4.300000
# 15                 GAME  4.286326
# 3                BEAUTY  4.278571
# 16   HEALTH_AND_FITNESS  4.277104
# 27             SHOPPING  4.259664
# 28               SOCIAL  4.255598
# 33              WEATHER  4.244000
# 29               SPORTS  4.223511
# 26         PRODUCTIVITY  4.211396
# 17       HOUSE_AND_HOME  4.197368
# 12               FAMILY  4.192272
# 25          PHOTOGRAPHY  4.192114
# 2     AUTO_AND_VEHICLES  4.190411
# 21              MEDICAL  4.189143
# 18   LIBRARIES_AND_DEMO  4.178462
# 14       FOOD_AND_DRINK  4.166972
# 7         COMMUNICATION  4.158537
# 6                COMICS  4.155172
# 22   NEWS_AND_MAGAZINES  4.132189
# 13              FINANCE  4.131889
# 10        ENTERTAINMENT  4.126174
# 5              BUSINESS  4.121452
# 31     TRAVEL_AND_LOCAL  4.109292
# 19            LIFESTYLE  4.094904
# 32        VIDEO_PLAYERS  4.063750
# 20  MAPS_AND_NAVIGATION  4.051613
# 30                TOOLS  4.047411
# 8                DATING  3.970769
# 0                   1.9  1.900000

# %% [markdown]
# **Plotting Category Wise Rating**

# %% [markdown]
# First we like would see the category wise Mean Rating and try to compare which App gets the better rating and better satisfying its users.

# %%
#plt.rcParams['figure.figsize'] = (16,5)
plt.figure(figsize=(16,5))
#plt.plot(x,'ro')
#plt.xticks(rotation = 90)
category_wise_rating.plot(kind='bar',x='Category',y='Rating',color='brown')
plt.ylim(4,5)
plt.xlabel('Category',fontsize=15)
plt.ylabel('Mean Rating',fontsize=15)
plt.title('Category Wise  Mean Rating',fontsize=25)
# Out:
# Text(0.5, 1.0, 'Category Wise  Mean Rating')

# %% [markdown]
# Here we can see the Event related apps are the top performing in terms of users satisfactions.
#
# This shows the Education related Apps also more desirable for the users,their high rating suggest why  the current generation knows going for the online education.Online education provide opertunities to the student especially girls in remote areas to access the learning material.
#
# Quite interesting !Beauty related apps are also among performing apps,able to satisfy ladies.That's a big deal!
#
# Most intersting thing to note is,Dating related Apps are among the worst performing Apps,broken expectation of many users to get into relationship.

# %% [markdown]
# **Plotting Density Of Rating**

# %% [markdown]
# Now we ll see the general rating given by users out of 5.
#
# It help us to know overall experience user got.

# %%
plt.rcParams['figure.figsize']=(10,7) #using Seaborn
sns.distplot(df['Rating'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The density rating graph shows the user's level of satisfaction using different Apps.By seeing data,we can people are giving on an avaerage more than 4 out of 5 which show that user's are nearly satisfied with the services.
# This ll help to comapare the performance of Apps in Google Playstore with that on other Play Store.
#
# Average of more than 4 rating gives an idea that users are actually liking this Apps on Google Store .
#
# This is also due to having an open platform which provide many new idea and opportunies to developer to grow and innovate according to the need of the people.

# %% [markdown]
# # **Category Wise Reviews**

# %% [markdown]
# The data show the hom much people intersted in giving reviews on any app,  whether they are highly impressed or highly disappointed by the services.
# They are generally less in number compared to their Installs.
# More number of review with diverse opinion have more trust building impact, as the customer are more comfortable with the Apps having with more reviews.

# %% [markdown]
# **Data Cleaning**

# %% [markdown]
# We need to first convert the String data type into Integer type for smooth processing.

# %%
df.loc[df['Category']=='1.9', 'Reviews']=0 #removing outliers

# %%
df['Reviews']=df['Reviews'].astype('int') #changing datatype of Reviews

# %%
category_wise_reviews=df.groupby('Category')['Reviews'].mean().sort_values(ascending=False)
print(category_wise_reviews)
# Out:
# Category
# COMMUNICATION          2.107138e+06
# SOCIAL                 2.105903e+06
# GAME                   1.385859e+06
# PHOTOGRAPHY            6.373631e+05
# VIDEO_PLAYERS          6.307439e+05
# SHOPPING               4.424662e+05
# ENTERTAINMENT          3.971688e+05
# TOOLS                  3.240629e+05
# PRODUCTIVITY           2.691438e+05
# EDUCATION              2.538191e+05
# TRAVEL_AND_LOCAL       2.427051e+05
# PERSONALIZATION        2.279238e+05
# MAPS_AND_NAVIGATION    2.237902e+05
# FAMILY                 2.080255e+05
# NEWS_AND_MAGAZINES     1.922292e+05
# SPORTS                 1.844536e+05
# WEATHER                1.781065e+05
# HEALTH_AND_FITNESS     1.111253e+05
# BOOKS_AND_REFERENCE    9.506090e+04
# FOOD_AND_DRINK         6.994748e+04
# COMICS                 5.638793e+04
# FINANCE                4.795281e+04
# HOUSE_AND_HOME         4.518619e+04
# LIFESTYLE              3.372457e+04
# DATING                 3.115931e+04
# BUSINESS               3.033598e+04
# ART_AND_DESIGN         2.637600e+04
# PARENTING              1.597218e+04
# AUTO_AND_VEHICLES      1.369019e+04
# LIBRARIES_AND_DEMO     1.220139e+04
# BEAUTY                 7.476226e+03
# MEDICAL                3.425432e+03
# EVENTS                 2.515906e+03
# 1.9                    0.000000e+00
# Name: Reviews, dtype: float64

# %%
df['Reviews'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# **Ploting Category Wise Reviews**

# %%
plt.rcParams['figure.figsize']=(18,15)
sns.barplot(x=category_wise_reviews, y=category_wise_reviews.index, data=df)
plt.xlabel('Review',fontsize=15)
plt.ylabel('Category',fontsize=15)
plt.title('Category Wise Reviews',fontsize=25)
# Out:
# Text(0.5, 1.0, 'Category Wise Reviews')

# %% [markdown]
# Higher reviews in categories of Communication and Social related Apps signifies their use and people's interest in knowing about them.
# Since Communication and Social Apps are some of the important sector where people remain being careful before using because of its effectiveness and privacy.
#
# The concerning issue is of low reviews in Medical Category despite having on 4th spot in availability,among the lowest in Installs and Review which I think have a great potential to improve and is necessary for the better health system for the reason.Government need to focus in e-Medical sector.
#
# Game remains one of the dominating category in every aspect,thanks to the upcoming generation more frequent on mobiles!

# %% [markdown]
# # **Type Of App With Respect To Purchase**

# %% [markdown]
# Two types of App are given with respect of the purchase,that is either they are free or  paid.
# Lets first check the percentage of Apps in Paid or Free.

# %%
df.loc[df['Type']=='0','Type']='Free' #replacing Type '0' with 'Free'
purchasability_wise_distribution=df['Type'].value_counts()

# %% [markdown]
# Ploting Type

# %%
'''from pygooglechart import PieChart3D

def python_pie3D() :
  # initialize chart object, 250 x 250 pixels
  f = PieChart3D(250, 250)'''
sizes = [215, 130, 245, 210]

def autopct(pct): # only show the label when it's > 10%
    return ('%.2f' % pct) if pct > 5 else ''
explosion=(0.2,0.2) #look like break away piece
plt.rcParams['figure.figsize']=(15,10)
purchasability_wise_distribution.plot(kind='pie',explode=explosion,autopct=autopct,shadow=True,startangle=140,fontsize=15)

# %% [markdown]
# Wow,Results are quite astonishing!Only 7-8% are paid Apps thus makes Google Play Store most popular among the users.
# Even middle class or poor can use this store optimally.

# %% [markdown]
# # **Category Wise Size**

# %% [markdown]
# Size matters!the popularity of any Apps also depend on how much storage it takes.Its could be understood the app having less size have a more chances of getting Install.
#
# Also This can't be ruled out that higher size cover more features which are also critical for their popularity.Higher size also provide better graphics,visuals and audio quality.

# %% [markdown]
# Cleaning The Data

# %%
df['Size'] = df['Size'].apply(lambda x: x.strip('+')) #removing '+' symbol

# %%
df['Size'] = df['Size'].apply(lambda x: x.replace(',', '')) #removing ',' symbol to convert into integers

# %%
df['Size'] = df['Size'].str.replace("M","000") #replacing 'M'(millions) with '000'

# %%
df['Size'] = df['Size'].str.replace("k","") #putting all data of size in kilobyte

# %%
df['Size'] = df['Size'].str.replace("1000+","1000", regex=True) #removing '+' symbol

# %%
df['Size'] = df['Size'].replace('Varies with device',np.nan) #replacing 'Vareis with device' with with np.nan for running the code

# %%
df['Size'] =df['Size'].astype(float) #changing data type of Size Coloumn

# %% [markdown]
# Distribution of Size with respect to Category

# %% [markdown]
# We ll see first average size of Apps in various categories .

# %%
category_wise_avg_size=df.groupby('Category')['Size'].mean().reset_index().sort_values(by='Category',ascending='True') #grouping of category with respect to size

# %%
print(category_wise_avg_size)
# Out:
#                Category          Size
# 0                   1.9   1000.000000
# 1        ART_AND_DESIGN   9325.483871
# 2     AUTO_AND_VEHICLES  17923.262667
# 3                BEAUTY  10939.029787
# 4   BOOKS_AND_REFERENCE  10217.842132
# 5              BUSINESS  11692.175000
# 6                COMICS  10669.994118
# 7         COMMUNICATION   9623.466038
# 8                DATING  14096.870755
# 9             EDUCATION  19137.366667
# 10        ENTERTAINMENT  20823.253333
# 11               EVENTS  11587.185965
# 12               FAMILY  26486.757697
# 13              FINANCE  15517.836156
# 14       FOOD_AND_DRINK  20841.165000
# 15                 GAME  43019.706601
# 16   HEALTH_AND_FITNESS  19904.109848
# 17       HOUSE_AND_HOME  12762.733824
# 18   LIBRARIES_AND_DEMO   9403.090244
# 19            LIFESTYLE  11879.830725
# 20  MAPS_AND_NAVIGATION  13850.562963
# 21              MEDICAL  17593.417512
# 22   NEWS_AND_MAGAZINES  10055.031481
# 23            PARENTING  20113.512963
# 24      PERSONALIZATION   8552.320282
# 25          PHOTOGRAPHY  14734.690551
# 26         PRODUCTIVITY  10480.529703
# 27             SHOPPING  14092.259204
# 28               SOCIAL  14906.340000
# 29               SPORTS  21890.784244
# 30                TOOLS   6032.180108
# 31     TRAVEL_AND_LOCAL  22981.929167
# 32        VIDEO_PLAYERS  13641.849618
# 33              WEATHER  10118.008772

# %% [markdown]
# Ploting Category Wise Size

# %%
category_wise_avg_size.plot(y='Category',x='Size', kind='scatter',color='brown')
plt.xlabel('Size in kilobyte',size=20)
plt.ylabel('Categories',size=20)
plt.title('Categories Wise Size',fontsize=25)
# Out:
# Text(0.5, 1.0, 'Categories Wise Size')

# %% [markdown]
# Quite surprising!despite having large size,Games related Apps still have one of the highest Installs.This could be mainly due to the craze among the children and youth for the games as well as they also attracted toward graphics,visual effect which makes Games attractive with large size.
#
# Travel and locals and Family having large size but their Installs are less as expected,developers need to reduce the size of this as per their utility.
#
# It depict Tools which having one of the lowest size still able to enter in Top 5 installs,which shows higher relevance of this type of Apps in daily need.

# %% [markdown]
# # **Distribution Of Content Rating With Respect to Age**

# %% [markdown]
# Age shows the which are prime targeted users for the developers.
#
# Some are general in nature while other are specically targeted to certain age like Comics related Apps generally for teens,while Dating Apps targeted toward mature 17+.
# It provide the taste of the population in different Ages.

# %%
from pandas._libs.hashtable import value_count
distribution_in_content=df['Content Rating'].value_counts()

# %% [markdown]
# Ploting the count of content rating with respect to Age

# %%
plt.rcParams['figure.figsize']=(10,5)
distribution_in_content.plot(kind='line',color='g') 
plt.xlabel('Age',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.title('Age vs Content Rating',fontsize=25)
# Out:
# Text(0.5, 1.0, 'Age vs Content Rating')

# %% [markdown]
# As we can see,absolute majority of the developers focuses for everyone means users of all ages.
# It also can be analysed that content rating has near funneling effect on age.
# As the number of Apps for a specific age is lesser as user get older.
# This can be understood,lower user bank would not generate much revenue
# thus very little developer would be interested in targeting smaller piece of population.

# %% [markdown]
# # **Android Version**

# %% [markdown]
# Version of android would enable us to understand about the technological upgradation among developers and users.
# How much users aware of the new development in Android as well as number of developer working on latest version of Androids.

# %% [markdown]
# Most Latest Version APPS in Google PlayStore

# %%
latest_version_app=df.loc[df['Android Ver']=='8.0 and up',['Category','App']]  #Android Version of 8.0 and up would be the latest version.

# %%
print(latest_version_app)
# Out:
#                  Category                              App
# 2484              MEDICAL                Clinic Doctor EHr
# 3240                TOOLS               Moto Suggestions ™
# 3275                TOOLS              Google Assistant Go
# 4460      PERSONALIZATION  Theme Android P for LG G7 & V35
# 6582   HEALTH_AND_FITNESS                        My BP Lab
# 10299               TOOLS                       FD CANNECT

# %% [markdown]
# Quiet Interesting!Tools Apps are on the most dominant in using latest version of the android,as it is necessary for tools to quickly get updated to survive with respect to the development  of Android.

# %%
df['Android Ver'].value_counts() #number of APPs in every Version
# Out:
# 4.1 and up            2451
# 4.0.3 and up          1501
# 4.0 and up            1375
# Varies with device    1362
# 4.4 and up             980
# 2.3 and up             652
# 5.0 and up             601
# 4.2 and up             394
# 2.3.3 and up           281
# 2.2 and up             244
# 4.3 and up             243
# 3.0 and up             241
# 2.1 and up             134
# 1.6 and up             116
# 6.0 and up              60
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              24
# 1.5 and up              20
# 4.4W and up             12
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %%
df.groupby(['Category'])['Android Ver'].value_counts().sort_values(ascending=False) #distribution of Category wise apps with respect to Android Version
# Out:
# Category            Android Ver
# FAMILY              4.1 and up      516
# GAME                4.1 and up      339
# FAMILY              4.0.3 and up    307
#                     4.0 and up      290
#                     2.3 and up      188
#                                    ...
# GAME                4.4W and up       1
#                     5.1 and up        1
# HEALTH_AND_FITNESS  2.0 and up        1
# PRODUCTIVITY        7.0 and up        1
# WEATHER             4.3 and up        1
# Name: Android Ver, Length: 529, dtype: int64

# %%
number_wise_distribution_of_android_ver=df['Android Ver'].value_counts().head(10) #Android version with respect to the its number of app

# %% [markdown]
# Ploting Android Version Which are at top10 in number.

# %%
plt.rcParams['figure.figsize']=(15,10)
def autopct(pct): # only show the label when it's > 10%
    return ('%.2f' % pct) if pct > 5 else ''

number_wise_distribution_of_android_ver.plot(title='ANDROID VERSION OF MOST COUNT', kind='pie',fontsize=20,autopct=autopct)
plt.title('ANDROID VERSION OF TOP10 COUNT',fontsize=25)
# Out:
# Text(0.5, 1.0, 'ANDROID VERSION OF TOP10 COUNT')

# %% [markdown]
# Here we can see,despite several updradation version 4.0 and 4.1 dominant in the market,with together they comprise nearly 50% of the total number of Apps.
#
# Point to note that latest update of Android that is Version 8.0 is no where in top 10 which show that people are still unaware of the upgradation or might be later version would not be much userfrindly,thus could not able to attract many users.

# %% [markdown]
# # **Price Distribution**

# %% [markdown]
# Apps are of two types either paid or free.Free means can be used by everyone while for paid ,users have to pay some price in US DOLLAR.
# Nearly 90% of Apps are free,while some App required to high price nearly 300-400$.
#
# Let see the most priced Apps!

# %% [markdown]
# Data Cleaning

# %%
df.loc[df['Price']=='Everyone','Price']='0' #APPs used by everyone can be taken as free of cost.

# %%
df['Price'] = df['Price'].apply(lambda x: x.strip('$')) #Removing dollar symbol from Price

# %%
df['Price'] = pd.to_numeric(df['Price']) #Converting into numeric form for operation

# %% [markdown]
# **Top Most Expensive Apps**

# %%
top10PaidApps = df[df['Type'] == 'Paid'].sort_values(by='Price', ascending=False).head(11) #segregating the paid Apps

# %%
top10PaidApps_df = top10PaidApps[['App', 'Installs']].drop(9934)

# %% [markdown]
# Ploting The Top Expensive App With Respect To The Installs

# %%
plt.figure(figsize=(15,12));
plt.pie(top10PaidApps_df.Installs, explode=None, labels=top10PaidApps_df.App, autopct='%1.1f%%', startangle=0);
plt.title('Top Expensive Apps Distribution',size = 20);
plt.legend(top10PaidApps_df.App, loc="lower right",title="Apps",fontsize = "xx-small")
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 128142 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 128142 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
#   Here we can see,one App nearly dominated the price domain.
#
#   I'm Rich developed by Armin Heinrich of lifestyle genre topped the most expensive app of nearly 400$ cost.
#   Its other genre like of finance also very expensive.

# %% [markdown]
# Correlation Of The Information Of All The Apps

# %% [markdown]
# At last we ll try to figure out the relation among the different information of the Apps.
#
# The Size,Price and other features would impact the Rating,Reviews and at last decides the Installs which is the ultimate goal of every developers.

# %%
df_corr=df.corr() #To find the correlation

# %%
df_corr
# Out:
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.068147  0.080984  0.051393 -0.021851
# Reviews   0.068147  1.000000  0.230671  0.643123 -0.009666
# Size      0.080984  0.230671  1.000000  0.163458 -0.022722
# Installs  0.051393  0.643123  0.163458  1.000000 -0.011688
# Price    -0.021851 -0.009666 -0.022722 -0.011688  1.000000

# %% [markdown]
# Developing a heatmap showing relation between various information of Apps

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df_corr)

# %% [markdown]
# By analysing heatmap,we can point out that Reviews and Installs are most closely related in a positive way.
#
# Price relation with every feature is near zero because for most of the Apps price are free.
#
# We can also see the little impact of rating of Rating on Installs because of the higher density of the Rating in between 4 to 5 out of 5.
#
# This can be attributed to the diversity in the features of App!

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# That it!after going through all the process and analysing various information,
#
# > Indented block
#
#
# we are moving toward the concluding our analysis.
#
# After several operation we come to know about the various aspect of the Dataset of Play Store.
# like Which Category of Apps are most available,their Installs Quantity,Reviews numbers as well as Size and Ratings they got and found the Games related Apps are the dominant one.
#
# 1-Family and Game related Apps are most available category.
#
# 2-Most Installed Category of Apps is Games and Communication.
#  Family related Apps not comes in even top5.
#
#
# 3-If we go through the Category of 'Art and Design',Sketch,draw & Paint is most installed Apps much more than its followed Apps.
#
# 4-All Category of Apps got more or less same rating in between 4 & 5.
#  The Event and Education Category got the maximum rating nearly 4.4.
#
# 5-By analysing Rating Density,we come to know that most number of user given rating between 4 & 5.
#
# 6-Communication and Social category of Apps got most number of reviews.
#  Might be duty to the sensitivity of privacy which user see befor using these Apps.
#
# 7-Nearly 93% of Apps are free thus make Android Market more popular store than others.
#
# 8-By looking at Category Wise Size,the most number of Category have average size in between 10MB and 20 MB.
#
#    Games occupies the maximum amount of space upto 40 MB still have a maximum number of Installs.
#
# 9-Most of the Apps are suitable for Everyone,as we increase the suitable age less and less number of Apps are targeted.
#
# 10-Most of the Apps are compatible with Android Version of 4.0 and 4.1.
#
#   Version of 8.0 despite being latest,not comes even in top 10 in compatibility with other Apps.
#
# 11-I'm Rich developed by Armin Heinrich of lifestyle genre topped the most expensive app of nearly 400$ cost. Its other genre like of finance also very expensive.
#
# 12-By analysing heatmap,we can point out that Reviews and Installs are most closely related in a positive way.
#
# Price relation with every feature is near zero because for most of the Apps price are free.
#
#
# Quiet long!but this analysis gave information not only about Apps but also the interest of the users as well as population which ll later help developer to make more user friendly Apps and can be utilized by everyone.
